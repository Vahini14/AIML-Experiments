# %% [markdown]
# <a href="https://colab.research.google.com/github/Vahini14/AIML-Experiments/blob/main/aiml5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/student-attendance-2023-24-feature-eng.csv')

# %%
print(df.head())  # View first few rows
# Out:
#   Unnamed: 0  Unnamed: 1                           SUBJECTS  DMGT   DAA   COA  \
# 0       S No     Roll No  Name of the Student / No.of Hours  53.0  49.0  58.0
# 1         48  22BFA33328             YETIGADDA PRAVEENKUMAR  48.0  47.0  57.0
# 2         56  22BFA33L14                    M PRAVEEN KUMAR  50.0  44.0  52.0
# 3         54  22BFA33L12    KOPPALA LEELA SIVAMARUTHI REDDY  47.0  46.0  50.0
# 4         20  22BFA33300                    MANNERU BHARATH  47.0  44.0  49.0
#
#    DBMS    PP    ES  AL-LAB  ...  Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# 0  59.0  53.0  33.0    26.0  ...          NaN          NaN          NaN
# 1  57.0  44.0  29.0    26.0  ...          NaN          NaN          NaN
# 2  45.0  48.0  32.0    22.0  ...          NaN          NaN          NaN
# 3  52.0  46.0  31.0    22.0  ...          NaN          NaN          NaN
# 4  52.0  45.0  31.0    20.0  ...          NaN          NaN          NaN
#
# ...

# %%
print(df.info())  # Check data types and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   73 non-null     object
#  1   Unnamed: 1   73 non-null     object
#  2   SUBJECTS     73 non-null     object
#  3   DMGT         73 non-null     float64
#  4   DAA          73 non-null     float64
#  5   COA          73 non-null     float64
#  6   DBMS         73 non-null     float64
#  7   PP           73 non-null     float64
#  8   ES           73 non-null     float64
#  9   AL-LAB       73 non-null     float64
#  10  DBMS-LAB     73 non-null     float64
#  11  PP-LAB       73 non-null     float64
#  12  LINUX-LAB    73 non-null     float64
#  13  Total        0 non-null      float64
#  14  Per          0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
print(df.describe())  # Summary statistics for numerical columns
# Out:
#             DMGT        DAA        COA       DBMS         PP         ES  \
# count  73.000000  73.000000  73.000000  73.000000  73.000000  73.000000
# mean   38.890411  38.958904  41.972603  41.767123  40.164384  26.027397
# std     5.443043   3.860190   5.700810   6.115828   4.160040   3.244536
# min    23.000000  27.000000  25.000000  25.000000  31.000000  18.000000
# 25%    36.000000  36.000000  40.000000  38.000000  38.000000  24.000000
# 50%    40.000000  40.000000  42.000000  41.000000  40.000000  26.000000
# 75%    42.000000  42.000000  45.000000  45.000000  43.000000  28.000000
# max    53.000000  49.000000  58.000000  59.000000  53.000000  33.000000
#
#           AL-LAB   DBMS-LAB     PP-LAB  LINUX-LAB  ...  Unnamed: 15  \
# count  73.000000  73.000000  73.000000  73.000000  ...          0.0
# mean   21.821918  19.424658  21.356164  22.136986  ...          NaN
# std     2.678839   3.222826   3.241955   2.719860  ...          NaN
# ...

# %%
print(df.describe())  # Descriptive statistics before handling missing values
# Out:
#             DMGT        DAA        COA       DBMS         PP         ES  \
# count  73.000000  73.000000  73.000000  73.000000  73.000000  73.000000
# mean   38.890411  38.958904  41.972603  41.767123  40.164384  26.027397
# std     5.443043   3.860190   5.700810   6.115828   4.160040   3.244536
# min    23.000000  27.000000  25.000000  25.000000  31.000000  18.000000
# 25%    36.000000  36.000000  40.000000  38.000000  38.000000  24.000000
# 50%    40.000000  40.000000  42.000000  41.000000  40.000000  26.000000
# 75%    42.000000  42.000000  45.000000  45.000000  43.000000  28.000000
# max    53.000000  49.000000  58.000000  59.000000  53.000000  33.000000
#
#           AL-LAB   DBMS-LAB     PP-LAB  LINUX-LAB  ...  Unnamed: 15  \
# count  73.000000  73.000000  73.000000  73.000000  ...          0.0
# mean   21.821918  19.424658  21.356164  22.136986  ...          NaN
# std     2.678839   3.222826   3.241955   2.719860  ...          NaN
# ...

# %%
threshold = 0.7  # Set a threshold for missing percentage
df = df.dropna(thresh=len(df) * threshold, axis=1)  # Drop columns with high missing percentage

# %%
# Subject columns to fill
subject_columns = ['DMGT', 'DAA', 'COA', 'DBMS', 'PP', 'ES', 'AL-LAB', 'DBMS-LAB', 'PP-LAB', 'LINUX-LAB']

# Fill missing values in subject columns with the mean
for column in subject_columns:
    df[column].fillna(df[column].mean(), inplace=True)

# Save the updated dataset (optional)
# df.to_csv("student_data_filled.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DMGT'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-5a058aee4585> in <cell line: 0>()
#       4 # Fill missing values in subject columns with the mean
# ...

# %%
column_names = ['Roll No', 'Name of the Student / No.of Hours', 'DMGT', 'DAA', 'COA', ...] # Add all your column names
df = pd.read_csv("/content/student-attendance-2023-24-feature-eng.csv", names=column_names, header=None)

# %%
# Subject columns to fill
subject_columns = ['DMGT', 'DAA', 'COA', ...] # Make sure names are consistent

# Fill missing values
for column in subject_columns:
    df[column].fillna(df[column].mean(), inplace=True)

# ... (rest of your code)
# Out:
# <ipython-input-19-a52cc433bec2>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mean(), inplace=True)

# %%
for column in subject_columns:
    df[column] = df[column].fillna(df[column].mean())

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Assuming your data is in a CSV file named "student_data.csv"
# and it has the structure you provided earlier

# 1. Load the dataset with appropriate header handling
column_names = ['S No', 'Roll No', 'Name of the Student / No.of Hours',
                'DMGT', 'DAA', 'COA', 'DBMS', 'PP', 'ES',
                'AL-LAB', 'DBMS-LAB', 'PP-LAB', 'LINUX-LAB', 'Total', 'Per']
df = pd.read_csv("student_data.csv", names=column_names, header=0)  # header=0 if you have a header row

# 2. Handle Missing Values
subject_columns = ['DMGT', 'DAA', 'COA', 'DBMS', 'PP', 'ES', 'AL-LAB', 'DBMS-LAB', 'PP-LAB', 'LINUX-LAB', 'Total', 'Per']
for column in subject_columns:
    df[column] = df[column].fillna(df[column].mean())

# 3. Feature Scaling (for numerical features)
numerical_features = subject_columns  # Assuming all subject columns and Total, Per are numerical
scaler = StandardScaler()
df[numerical_features] = scaler.fit_transform(df[numerical_features])

# 4. (Optional) Feature Engineering - Create new features if needed
# Example: Create a feature for the average lab score
df['Avg_Lab_Score'] = df[['AL-LAB', 'DBMS-LAB', 'PP-LAB', 'LINUX-LAB']].mean(axis=1)

# 5. (Optional) Remove unnecessary columns
# You might want to remove columns like 'S No', 'Roll No', 'Name of the Student / No.of Hours'
# if they are not relevant for your analysis.
# df = df.drop(['S No', 'Roll No', 'Name of the Student / No.of Hours'], axis=1)

# Save the preprocessed dataset (optional)
# df.to_csv("student_data_preprocessed.csv", index=False)

# Display the preprocessed DataFrame (for inspection)
print(df.head())

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Assuming your data is in a CSV file named "student_data.csv"
# and it has the structure you provided earlier

# 1. Load the dataset with appropriate header handling
column_names = ['S No', 'Roll No', 'Name of the Student / No.of Hours',
                'DMGT', 'DAA', 'COA', 'DBMS', 'PP', 'ES',
                'AL-LAB', 'DBMS-LAB', 'PP-LAB', 'LINUX-LAB', 'Total', 'Per']
df = pd.read_csv("/content/student-attendance-2023-24-feature-eng.csv", names=column_names, header=0)  # header=0 if you have a header row

# 2. Handle Missing Values
subject_columns = ['DMGT', 'DAA', 'COA', 'DBMS', 'PP', 'ES', 'AL-LAB', 'DBMS-LAB', 'PP-LAB', 'LINUX-LAB', 'Total', 'Per']
for column in subject_columns:
    df[column] = df[column].fillna(df[column].mean())

# 3. Feature Scaling (for numerical features)
numerical_features = subject_columns  # Assuming all subject columns and Total, Per are numerical
scaler = StandardScaler()
df[numerical_features] = scaler.fit_transform(df[numerical_features])

# 4. (Optional) Feature Engineering - Create new features if needed
# Example: Create a feature for the average lab score
df['Avg_Lab_Score'] = df[['AL-LAB', 'DBMS-LAB', 'PP-LAB', 'LINUX-LAB']].mean(axis=1)

# 5. (Optional) Remove unnecessary columns
# You might want to remove columns like 'S No', 'Roll No', 'Name of the Student / No.of Hours'
# if they are not relevant for your analysis.
# df = df.drop(['S No', 'Roll No', 'Name of the Student / No.of Hours'], axis=1)

# Save the preprocessed dataset (optional)
# df.to_csv("student_data_preprocessed.csv", index=False)

# Display the preprocessed DataFrame (for inspection)
print(df.head())
# Out:
#                                                                                       S No  \
# S No Roll No    Name of the Student / No.of Hours 53.0 49.0 58.0 59.0 53.0 33.0 26.0  24.0
# 48   22BFA33328 YETIGADDA PRAVEENKUMAR            48.0 47.0 57.0 57.0 44.0 29.0 26.0  24.0
# 56   22BFA33L14 M PRAVEEN KUMAR                   50.0 44.0 52.0 45.0 48.0 32.0 22.0  22.0
# 54   22BFA33L12 KOPPALA LEELA SIVAMARUTHI REDDY   47.0 46.0 50.0 52.0 46.0 31.0 22.0  20.0
# 20   22BFA33300 MANNERU BHARATH                   47.0 44.0 49.0 52.0 45.0 31.0 20.0  20.0
#
#                                                                                       Roll No  \
# S No Roll No    Name of the Student / No.of Hours 53.0 49.0 58.0 59.0 53.0 33.0 26.0     28.0
# 48   22BFA33328 YETIGADDA PRAVEENKUMAR            48.0 47.0 57.0 57.0 44.0 29.0 26.0     24.0
# 56   22BFA33L14 M PRAVEEN KUMAR                   50.0 44.0 52.0 45.0 48.0 32.0 22.0     26.0
# ...

# %%
import pandas as pd

# ... (your previous code for loading and preprocessing data) ...

# Subject columns to sum for 'Total'
subject_columns = ['DMGT', 'DAA', 'COA', 'DBMS', 'PP', 'ES', 'AL-LAB', 'DBMS-LAB', 'PP-LAB', 'LINUX-LAB']

# Calculate 'Total' by summing subject columns
df['Total'] = df[subject_columns].sum(axis=1)

# Calculate 'Per' (Percentage)
total_marks = len(subject_columns) * 100  # Assuming each subject has a maximum of 100 marks
df['Per'] = (df['Total'] / total_marks) * 100

# %%
print(df.head())
# Out:
#                                                                                       S No  \
# S No Roll No    Name of the Student / No.of Hours 53.0 49.0 58.0 59.0 53.0 33.0 26.0  24.0
# 48   22BFA33328 YETIGADDA PRAVEENKUMAR            48.0 47.0 57.0 57.0 44.0 29.0 26.0  24.0
# 56   22BFA33L14 M PRAVEEN KUMAR                   50.0 44.0 52.0 45.0 48.0 32.0 22.0  22.0
# 54   22BFA33L12 KOPPALA LEELA SIVAMARUTHI REDDY   47.0 46.0 50.0 52.0 46.0 31.0 22.0  20.0
# 20   22BFA33300 MANNERU BHARATH                   47.0 44.0 49.0 52.0 45.0 31.0 20.0  20.0
#
#                                                                                       Roll No  \
# S No Roll No    Name of the Student / No.of Hours 53.0 49.0 58.0 59.0 53.0 33.0 26.0     28.0
# 48   22BFA33328 YETIGADDA PRAVEENKUMAR            48.0 47.0 57.0 57.0 44.0 29.0 26.0     24.0
# 56   22BFA33L14 M PRAVEEN KUMAR                   50.0 44.0 52.0 45.0 48.0 32.0 22.0     26.0
# ...

# %%
plt.scatter(df['Total'], df['Per'])
plt.xlabel('Total Score')
plt.ylabel('Percentage')
plt.title('Total Score vs. Percentage')
plt.show()
